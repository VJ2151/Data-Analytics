# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('salary.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
X = df[['YearsExperience']]
y = df['Salary']
print(X,y)
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# ...

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test,y_test,color="red")
plt.plot(X_train, model.predict(X_train),color="blue")
plt.title("salart vs experience(test set)")
plt.xlabel("years of experience")
plt.ylabel("salary")
plt.show()

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Step 6 - Predicting for new values
# Fixed the dictionary syntax and bracket placement
new_X_values_df = pd.DataFrame({'YearsExperience': [1, 3, 5, 8, 12, 15, 20, 25]})

# Predict using your trained model
new_y_pred = model.predict(new_X_values_df)

print('Predictions for new experience values (1, 3, 5, 8, 12, 15, 20, 25):\n', new_y_pred)

# Step 7 - Model Evaluation
# Ensure y_test and y_pred (from your test set) are already defined
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("\nModel Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R2 Score: {r2}")
# Out:
# Predictions for new experience values (1, 3, 5, 8, 12, 15, 20, 25):
#  [ 36092.67427736  54717.82453082  73342.97478427 101280.70016446
#  138531.00067138 166468.72605157 213031.60168521 259594.47731886]
#
# Model Evaluation Metrics:
# Mean Absolute Error (MAE): 2446.1723690465055
# Mean Squared Error (MSE): 12823412.298126549
# R2 Score: 0.988169515729126
