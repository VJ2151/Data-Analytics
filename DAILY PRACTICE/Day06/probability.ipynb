# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("titanic.csv")
df=df[["gender","survived"]]
df.dropna(inplace=True)
total=len(df)
print(total)
# Out:
# 891

# %%
total_female=len(df[df["gender"]=='female'])
print("total_female",total_female)
total_male=len(df[df["gender"]=='male'])
print("total_female",total_male)
# Out:
# total_female 314
# total_female 577

# %%
p_female=total_female/total
p_male=total_male/total
print("p_female",p_female)
print("p_male",p_male)
# Out:
# p_female 0.35241301907968575
# p_male 0.6475869809203143

# %%
total_survived=len(df[df["survived"]==1])
print("total_survived",total_survived)
total_did_not_survived=len(df[df["survived"]==0])
print("total_did_not_survived",total_did_not_survived)
p_survived=total_survived/total
p_not_survived=total_did_not_survived/total
# Out:
# total_survived 342
# total_did_not_survived 549

# %%
print("/n marginal probabilities:")
print(f"p(gender=female):{p_female:.3f}")
print(f"p(gender=male):{p_male:.3f}")
print(f"p(survived=1):{p_survived:.3f}")
print(f"p(survived=0):{p_not_survived:.3f}")
# Out:
# /n marginal probabilities:
# p(gender=female):0.352
# p(gender=male):0.648
# p(survived=1):0.384
# p(survived=0):0.616

# %% [markdown]
# # joint probabilities

# %%
p_female_survived = len(df[(df['gender'] == 'female') & (df['survived'] == 1)]) / total
p_male_survived = len(df[(df['gender'] == 'male') & (df['survived'] == 1)]) / total
p_female_not_survived = len(df[(df['gender'] == 'female') & (df['survived'] == 0)]) / total
p_male_not_survived = len(df[(df['gender'] == 'male') & (df['survived'] == 0)]) / total

print("/n Joint probabilities:")
print(f"p(female, Survived = 1):{p_female_survived:.3f}")
print(f"p(female, Survived = 0):{p_female_not_survived:.3f}")
print(f"p(male, Survived = 1):{p_male_survived:.3f}")
print(f"p(male, Survived = 0):{p_male_not_survived:.3f}")
# Out:
# /n Joint probabilities:
# p(female, Survived = 1):0.262
# p(female, Survived = 0):0.091
# p(male, Survived = 1):0.122
# p(male, Survived = 0):0.525

# %% [markdown]
# #  conditional Probability

# %%
p_survived_given_female = p_female_survived/p_female
print(f"P(survived=1 | gender = female):{p_survived_given_female:.3f})")
p_survived_given_male = p_male_survived/p_male
print(f"P(survived=1 I gender = male):{p_survived_given_male:.3f}")
# Out:
# P(survived=1 | gender = female):0.742)
# P(survived=1 I gender = male):0.189

# %% [markdown]
# # Exercise: Use diabetes dataset

# %% [markdown]
# ### 1. What is the probability that a randomly selected person in the dataset has diabetes? (Marginal probability)
# ### 2. What is the probability that a person has diabetes and is obese (BMI > 30)? (Joint probability of independent events)
# ### 3. What is the probability that a person has diabetes given that their glucose level is high (e.g., Glucose > 140)? (Joint probability of dependent events / Conditional probability)

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### 1. What is the probability that a randomly selected person in the dataset has diabetes? (Marginal probability)

# %%
df=df[["BMI","Outcome"]]
df.dropna(inplace=True)
total=len(df)
print(total)
# Out:
# 768

# %%
daibetic=len(df[df["Outcome"]==1])
print("total_daibetic",total_survived)
not_daibetic=len(df[df["Outcome"]==0])
print("not_daibetic",not_daibetic)
d_daibetic=daibetic/total
d_not_daibetic=not_daibetic/total
# Out:
# total_daibetic 342
# not_daibetic 500

# %%
print("/n marginal probabilities:")
print(f"p(daibetic):{daibetic:.3f}")
print(f"p(Non daibetic):{not_daibetic:.3f}")
print(f"p(Outcome=1):{d_daibetic:.3f}")
print(f"p(Outcome=0):{d_not_daibetic:.3f}")
# Out:
# /n marginal probabilities:
# p(daibetic):268.000
# p(Non daibetic):500.000
# p(Outcome=1):0.349
# p(Outcome=0):0.651

# %% [markdown]
# ### 2. What is the probability that a person has diabetes and is obese (BMI > 30)? (Joint probability of independent events)

# %%
p_daibetic_survived = len(df[(df['BMI'] >30) & (df['Outcome'] == 1)]) / total
p_non_daibetic_survived = len(df[(df['BMI']>30) & (df['Outcome'] == 0)]) / total


print("/n Joint probabilities:")
print(f"p(BMI > 30, Outcome = 1):{p_daibetic_survived:.3f}")
print(f"p(BMI > 30, Outcome = 0):{p_non_daibetic_survived:.3f}")
# Out:
# /n Joint probabilities:
# p(BMI > 30, Outcome = 1):0.280
# p(BMI > 30, Outcome = 0):0.326

# %% [markdown]
# ### 3. What is the probability that a person has diabetes given that their glucose level is high (e.g., Glucose > 140)? (Joint probability of dependent events / Conditional probability)

# %%
p_daibetic_survived = len(df[(df['Glucose'] >140) & (df['Outcome'] == 1)]) / total
p_non_daibetic_survived = len(df[(df['Glucose']>140) & (df['Outcome'] == 0)]) / total

print("/n conditional probabilities:")
print(f"p(Glucose > 140, Outcome = 1):{p_daibetic_survived:.3f}")
print(f"p(Glucose > 140, Outcome = 0):{p_non_daibetic_survived:.3f}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Glucose'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ...

# %%
p_daibetic_survived = p_female_survived/p_female
print(f"P(survived=1 | gender = female):{p_survived_given_female:.3f})")
p_non_daibetic_survivede = p_male_survived/p_male
print(f"P(survived=1 I gender = male):{p_survived_given_male:.3f}")
