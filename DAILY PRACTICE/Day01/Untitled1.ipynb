# %%
import numpy as np

# %%
a=np.array([10,20,30,40,50,60,70])
a
# Out:
# array([10, 20, 30, 40, 50, 60, 70])

# %%
b=a[0:5]
print("orignal a:",a)
print("shallow copy b:",b)
# Out:
# orignal a: [10 20 30 40 50 60 70]
# shallow copy b: [10 20 30 40 50]

# %%
b[0]=999
print(f"a = {a},\nb = {b}")
# Out:
# a = [999  20  30  40  50  60  70],
# b = [999  20  30  40  50]

# %%
c = b.copy()
c[0]=999
print(f"a = {a},\nb = {b}")
# Out:
# a = [10 20 30 40 50 60 70],
# b = [999  20  30  40  50]
