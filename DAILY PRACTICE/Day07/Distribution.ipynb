# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from scipy.stats import binom

# %%
n = 5  # total Number Of Students
k = 3 # student Likes Python
p = 0.66  # probability that a student likes Python

probability=binom.pmf(k,n,p)

print(f"The probability that exactly {k} out of {n} students like Python is : {probability:.4f}")
# Out:
# The probability that exactly 3 out of 5 students like Python is : 0.3323

# %% [markdown]
# ####  hospitals records show that  of patients suffering from a specifiic diseses ,"75% die of it.what  is the probability that of six randomly selected patients,four will recover ? (k=4,n=5,p=0.25)"

# %%
n = 6   # total Number Of Students
k = 4 # student Likes Python
p = 0.25  # probability that a student likes Python

probability=binom.pmf(k,n,p)

print(f"The probability that exactly {k} out of {n} students like Python is : {probability:.4f}")
# Out:
# The probability that exactly 4 out of 6 students like Python is : 0.0330

# %% [markdown]
# #### A (blindfolded) marksman finds that on the average, he hits the target 4 times out of 5. If he fires 4 shots, what is a probability of (a) more than 2 hits and (b) at least 3 misses?

# %%
p=4/5
n=4
print(binom

# %% [markdown]
# #### Normally, 65% of all the students who appear for C-DAC entrance test clear it.
# #### 50 students from a coaching class have appeared for C-DAC March 2024 entrance test. What is the probability that none of them will clear it? What is the probability that more than 40 will clear it?

# %%
# Poisson distribution

# %% [markdown]
# #### A COMPANY FINDS THAT ON AN AVERAGE ITS DEFECTIVE PRIDUCTS RATE IS 8 PRIDUCTS A DAY. FIND THE PROBABILITY OF 4 DEFECTIVE PRODUCTS IN A DAY

# %%
from scipy.stats import poisson
mu=8 # lambda
x=4
print(poisson.pmf(x,mu))
# Out:
# 0.057252288495362
