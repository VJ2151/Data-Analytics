# %%
import pandas as pd

# %%
df_2015=pd.read_csv("marathon_results_2015.csv")
df_2016=pd.read_csv("marathon_results_2016.csv")
df_2017=pd.read_csv("marathon_results_2017.csv")

# %%
#concatinate the dataset into the single dataframe
df=pd.concat([df_2015,df_2016,df_2017])

# %%
# get the total number of rows in orignal dataframe
original_row_count=len(df)
original_row_count
# Out:
# 79638

# %%
# perform simple random sampling (selecting 1/10th of the records)
sample_df=df.sample(frac=0.1,random_state=42)
sample_df
# Out:
#        Unnamed: 0    Bib                 Name  Age M/F              City  \
# 24038     24038.0  31350    Labonte, Laura R.   34   F       Charlestown
# 20218     20218.0  21352        Vargas, Mario   64   M    Shaker Heights
# 23755     23755.0  27235  Wilkins, Stephen D.   53   M        Dorchester
# 1447       1447.0   4337     Johnson, David T   32   M           Brandon
# 25121         NaN  26089       Bashor, Mari W   67   F        Sacramento
# ...           ...    ...                  ...  ...  ..               ...
# 23322     23322.0  11427        Silwal, Suman   45   M            Pelham
# 5102          NaN  10536         Baganz, Paul   62   M       Fond Du Lac
# 12821     12821.0  12730       Strutz, Nicole   22   F        Two Rivers
# 13241         NaN  21185    Greengrass, Suzie   45   F              Cary
# 8893       8893.0  13873  Fitzgerald, Vanessa   38   F  Long Island City
#
#       State Country Citizen Unnamed: 9  ...      30K      35K      40K  \
# ...

# %%
# Get the total number of rows in the sampled dataframe
sample_row_count=len(sample_df)
sample_row_count
# Out:
# 7964

# %%
original_row_count
# Out:
# 79638

# %%
print("First few rows of og dataframe: ")
print(df.head())
print("\n First few rows of the sampled dataframe: ")
print(sample_df.head())
# Out:
# First few rows of og dataframe:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:32:00  1:47:59  2:02:39  0:04:56         -
# 1     NaN        NaN  ...  1:31:59  1:47:59  2:02:42  0:04:58         -
# 2     NaN        NaN  ...  1:32:00  1:47:59  2:03:01  0:04:59         -
# 3     NaN        NaN  ...  1:32:00  1:48:03  2:03:47  0:05:00         -
# 4     NaN        NaN  ...  1:32:00  1:47:59  2:03:27  0:05:00         -
#
# ...

# %%
print(f"Number of rows of og dataframe: {original_row_count}")
print(f"\nNumber of  rows of the sampled dataframe: {sample_row_count} ")
# Out:
# Number of rows of og dataframe: 79638
#
# Number of  rows of the sampled dataframe: 7964

# %%
sample_df = df.iloc[::7]
sample_df
# Out:
#        Unnamed: 0    Bib                  Name  Age M/F               City  \
# 0             0.0      3        Desisa, Lelisa   25   M               Ambo
# 7             7.0      1       Keflezighi, Meb   39   M          San Diego
# 14           14.0     76         Goffi, Danilo   42   M  Parabiago - Milan
# 21           21.0     32  Zywicki, Benjamin P.   26   M         Louisville
# 28           28.0    106          Glaz, Daniel   32   M            Chicago
# ...           ...    ...                   ...  ...  ..                ...
# 26376     26376.0  25766   Miranda, Denisse C.   40   F         Long Beach
# 26383     26383.0  25182           Trang, Danh   30   M      San Francisco
# 26390     26390.0  28988        Taylor, Robert   56   M      Ft Lauderdale
# 26397     26397.0  15536    Coffman, Steven D.   69   M      East Sandwich
# 26404     26404.0  25141        Quinn, Adam H.   19   M            Belmont
#
# ...

# %%
sample_df = df.iloc[::7,:]
sample_df
# Out:
#        Unnamed: 0    Bib                  Name  Age M/F               City  \
# 0             0.0      3        Desisa, Lelisa   25   M               Ambo
# 7             7.0      1       Keflezighi, Meb   39   M          San Diego
# 14           14.0     76         Goffi, Danilo   42   M  Parabiago - Milan
# 21           21.0     32  Zywicki, Benjamin P.   26   M         Louisville
# 28           28.0    106          Glaz, Daniel   32   M            Chicago
# ...           ...    ...                   ...  ...  ..                ...
# 26376     26376.0  25766   Miranda, Denisse C.   40   F         Long Beach
# 26383     26383.0  25182           Trang, Danh   30   M      San Francisco
# 26390     26390.0  28988        Taylor, Robert   56   M      Ft Lauderdale
# 26397     26397.0  15536    Coffman, Steven D.   69   M      East Sandwich
# 26404     26404.0  25141        Quinn, Adam H.   19   M            Belmont
#
# ...

# %%
# how good is our sampling?
# same code as before for sample random sampling ....
df[['Hours','Minutes','Seconds']] = df['Official Time'].str.split(":",expand=True)
df['Hours']=df['Hours'].astype(int)
df['Minutes']=df['Minutes'].astype(int)
df['Seconds']=df['Seconds'].astype(int)

df['finish_time_in_seconds']=(
    df['Hours']*3600+
    df['Minutes']*60+
    df['Seconds']
)
df['finish_time_in_seconds']
# Out:
# 0         7757
# 1         7788
# 2         7822
# 3         7847
# 4         7849
#          ...
# 26405    25779
# 26406    26219
# 26407    26377
# 26408    26444
# 26409    28694
# Name: finish_time_in_seconds, Length: 79638, dtype: int64

# %%
# Split the Pace string into two new columns
df[['Pace_Minutes', 'Pace_Seconds']] = df['Pace'].str.split(':', expand=True).astype(int)

# Calculate total seconds (Pace usually doesn't have an 'Hours' component)
df['Pace_in_seconds'] = (
    df['Pace_Minutes'] * 60 + 
    df['Pace_Seconds']
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 2
#       1 # Split the Pace string into two new columns
# ----> 2 df[['Pace_Minutes', 'Pace_Seconds']] = df['Pace'].str.split(':', expand=True).astype(int)
#       4 # Calculate total seconds (Pace usually doesn't have an 'Hours' component)
#       5 df['Pace_in_seconds'] = (
#       6     df['Pace_Minutes'] * 60 +
#       7     df['Pace_Seconds']
#       8 )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:4660, in DataFrame.__setitem__(self, key, value)
#    4658     self._setitem_frame(key, value)
#    4659 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4660     self._setitem_array(key, value)
#    4661 elif isinstance(value, DataFrame):
#    4662     self._set_item_frame_value(key, value)
#
# ...
