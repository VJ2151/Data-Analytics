# %%
import pandas aspd
import numpy as np
import matplotlib.pyplot

# %%
data = {
    'Tom': [10, 'A', 10.5, 'B', 20, 30, 'C', 40.2, 50, 'D'],
    'Brick': ['X', 1, 2.2, 'Y', 3, 4, 'Z', 5.5, 6, 'W'],
    'Harry': [100, 200, 'Gold', 300.5, 'Silver', 400, 500, 'Bronze', 600.1, 700]
}

# Creating two versions with Boolean indexing
df1 = pd.DataFrame(data, index=[True, False, True, False, True, False, True, False, True, False])
df2 = df1.copy()

df1.to_csv('file1.csv')
df2.to_csv('file2.csv')
print("CSV files created successfully.")
